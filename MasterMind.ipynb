# %% [markdown]
# # Welcome to MasterMind
# *Hello dear user,*
# I'm a suppervillain character appearing in comic books
# Known for my purple domino mask and green question mark
# My daily costume is a green suit and a bolerand i'm always carrying a special question mark shaped cane.
# I'm obsessed with riddles, puzzles and word games
# I love making people use their noodles with some brain teasers
# If you didn't guess who i'am then it's better for to not get to my world
# I'm Edward Nigma known as the riddler
# If you would like to join my clan to defeat Batman you have to collect x points
# Each stop worth 10 points and if you are stuck just type "hint" and i'll be right for your assistance

# %%
"""
DocString:
    2 Stages 
        9 questionns and one bonus
Think, Think and Think

"""
import time
from sys import exit
points=0
user_info=[]
chances = 2

#Get to kno you
def intro():
    global user_info
    print("""
        Before starting the game i would like to know you
        """)
    time.sleep(1)
    print("""
        How would you like to be called?
        """)
    name=input(">  \n")
    user_info.append(name)
    print("""
        What is your favourite color
        """)   
    color=input(">  \n")
    user_info.append(color)
    print("""
        What is your destination for the trip of your dreams?
        """)
    dest=input(">  \n")
    user_info.append(dest)
    stage_1()
    
    
#First stage
def stage_1():
    global chances
    while chances > 0:
        print("""
        Welcome to the first stage, In this stage you will have to answer 4 questions. Only ONE WORD or a NUMBER are considered as an answer ..
        """)
        time.sleep(1)
        print("""
        Let's get started with the first question.
        """)
        time.sleep(1)
        question_1()

        
def question_1():
    global points
    print("""
        Jimmy's mother have four children: Monday, Tuesday,Wednesday and ...?
        """)
    Q1=input(">  \n")
    if Q1.upper() == "JIMMY":
        print("You are smart, keep going")
        points += 10
    
    elif Q1.upper() == "HINT":
        print(""""
        Read the question carefully!
        """)
        time.sleep(2)
        print("""
       Jimmy's mother have four children: Monday, Tuesday,Wednesday and ...?
        """)
        QH1=input(">  \n")
        if QH1.upper() == "JIMMY":
            points += 7
        else:
            print("""Incorrect answer""")
            
        
    else:
        print("Incorrect answer")
    question_2()
        
        
        
        
def question_2():
    global points
    print(""""
    in a year there are 12 months, seven months have 31 days. How many months have 28 days
    """)
    Q2=input(">  \n")
    if Q2.upper() == "TWELVE" or Q2 == "12":
    
        print ("You are smart, keep going")
        points += 10
    
    elif Q2.upper() == "HINT":
        print(""""
        It's a tricky question read it carefully
        """)
        time.sleep(2)
        print("""
       in a year there are 12 months, seven months have 31 days. How many months have 28 days
        """)
        QH2=input(">  \n")
        if QH2.upper() == "TWELVE" or QH2 == "12":
            print("Good job")
            points += 7
        else:
            print("""Incorrect answer""")
            
        
    else:
        print("Incorrect answer")
    question_3()
    
    
    
def question_3():
    global points
    print(""""
    Mr and Mrs smith have 6 daughters and each daughter has two brothers. How many people are in the smith family?
    """)
    Q3=input(">  \n")
    if Q3.upper() == "TEN" or Q3 == "10":
    
        print ("You are smart, keep going")
        points += 10
        print (points)
    
    elif Q3.upper() == "HINT":
        print(""""
        The couple have 8 children! 
        """)
        time.sleep(2)
        print("""
        Mr and mrs smith have 6 daughters and each daughter has two brothers how many people are in the smith family?
        """)
        QH3=input(">  \n")
        if QH3.upper() == "TEN" or QH3 == "10":
            print("Good job")
        else:
            print("""Incorrect answer""")
            
        
    else:
        print("Incorrect answer")
    question_4()
    
def question_4():
    global points
    global user_info
    global chances
    print("""
    1=5\n
    2=25\n
    3=325\n
    4=4325\n
    5=?
    """)
    Q4=input(">  \n")
    if Q4 == "1" or Q4 == "one":
        points += 10
    
    elif Q4.upper() == "HINT":
        print(""""
        Look at the first equality
        """)
        time.sleep(2)
        print("""
            1=5\n
            2=25\n
            3=325\n
            4=4325\n
            5=?
            """)
        QH4=input(">  \n")
        if QH4 == "1":
            points += 7
        else:
            print("""Incorrect answer""")
            
        
    else:
        print("Incorrect answer")
        
##Points test
    if points >= 37:
        stage_2()
    else:
        if chances > 1:
            print(f""""
        Let's try again""",user_info[0],
              """Remember you can use the word hint for assistance and you have only 1 chance remaining
        """)
            chances -= 1
            points = 0
            stage_1()
        else:
            fail()
            
def fail():
    global user_info
    print("""
     ▄· ▄▌      ▄• ▄▌    ▄▄▌              .▄▄ · ▄▄▄ .
▐█▪██▌▪     █▪██▌    ██•  ▪     ▪     ▐█ ▀. ▀▄.▀·
▐█▌▐█▪ ▄█▀▄ █▌▐█▌    ██▪   ▄█▀▄  ▄█▀▄ ▄▀▀▀█▄▐▀▀▪▄
 ▐█▀·.▐█▌.▐▌▐█▄█▌    ▐█▌▐▌▐█▌.▐▌▐█▌.▐▌▐█▄▪▐█▐█▄▄▌
  ▀ •  ▀█▄▀▪ ▀▀▀     .▀▀▀  ▀█▄▀▪ ▀█▄▀▪ ▀▀▀▀  ▀▀▀ 
    """)
    print(f"{user_info[0]}: Would you like to play again? (Y/N)")
    replay = input("> ")
    replay = replay.lower()
    
    if replay == 'y':
        stage_1()
        
    else:
        print(f"Thanks for playing {user_info[0]}!")
        exit(0)

    
def stage_2():
    global points
    print("""
            Congratulations! you have passed to second stage which is a little bit harder
            """)
    time.sleep(1)
    print("""
        Let's get started with the first question.
        """)
    time.sleep(1)
    question_5()
    
def question_5():
    global points
    print(""""
    give me food i'll live, give me water i'll die, what'am ?
    """)
    Q5=input(">  \n")
    if Q5.upper() == "FIRE":
        points += 10
    
    elif Q5.upper() == "HINT":
        print(""""
        People use me to cook food
        """)
        time.sleep(2)
        print("""
            give me food i'll live, give me water i'll die, what'am?
            """)
        QH5=input(">  \n")
        if QH5.upper() == "FIRE":
            print("good job")
            points += 7
        else:
            print("""Incorrect answer""")
    else:
        print("Incorrect answer")
    question_6()
    

def question_6():
    global points
    print("""
    What is black and white and red all over? 
    """)
    Q6=input(">  \n")
    if Q6.upper() == "NEWSPAPER":
    
        print ("You are smart, keep going")
        points += 10
    
    elif Q6.upper() == "HINT":
        print(""""
        I provide people with news
        """)
        time.sleep(2)
        print("""
            What is black and white and red all over?
            """)
        QH6=input(">  \n")
        if QH6.upper() == "NEWSPAPER":
            print("good job")
            points += 7
        else:
            print("""Incorrect answer""")
    else:
        print("Incorrect answer")
    question_7()
    
def question_7():
    global points
    print("""
    my life can be measured in hours, i serve for being devoured. Thin,i'am quick. fat i'm slow. Wind is my foe?
    """)
    Q7=input(">  \n")
    if Q7.upper() == "CANDLE":
    
        print ("You are smart, keep going")
        points += 10
    
    elif Q7.upper() == "HINT":
        print(""""
        You have to light me up and i'm made with wax
        """)
        time.sleep(2)
        print("""
            my life can be measured in hours, i serve for being devoured. Thin,i'am quick. fat i'm slow. Wind is my foe?
            """)
        QH7=input(">  \n")
        if QH7.upper() == "CANDLEji":
            print("good job")
            points += 7
        else:
            print("""Incorrect answer""")
    else:
        print("Incorrect answer")
    question_8()
    
def question_8():
    global points
    print("""
    what stinks when living and smells good when dead?
    """)
    Q8=input(">  \n")
    if Q8.upper() == "BACON":
    
        print ("You are smart, keep going")
        points += 10
    
    elif Q8.upper() == "HINT":
        print(""""
        I'm a meat that americans use me in breakfast
        """)
        time.sleep(2)
        print("""
            what stinks when living and smells good when dead?
            """)
        QH8=input(">  \n")
        if QH8.upper() == "BACON":
            print("good job")
            points += 7
        else:
            print("""Incorrect answer""")
    else:
        print("Incorrect answer")
    question_9()
    

    
def question_9():
    global points
    print("""
    I have a tail, a head and no legs, and i have a round shape. what'am i?
    """)
    Q9=input(">  \n")
    if Q9.upper() == "COIN":
    
        print ("You are smart, keep going")
        points += 10
    
    elif Q9.upper() == "HINT":
        print(""""
        people use me everyday to buy things and you can flip me over
        """)
        time.sleep(2)
        print("""
            I have a tail, a head and no legs, and i have a round shape. what'am i?
            """)
        QH9=input(">  \n")
        if QH9.upper() == "SECRET":
            print("good job")
            points += 7
        else:
            print("""Incorrect answer""")
    else:
        print("Incorrect answer")
    bonus()
    
def bonus():
    global points
    print("""
    This is a bonus question for you to catch up and join my world !
    """)
    time.sleep(1)
    print("""
    Who is my worst ennemy?
    """)

    QB=input(">  \n")
    if QB.upper() == "BATMAN":
        points += 10
    else:
        print("Incorrect answer")
    verification()
    
def verification():
    global points
    global user_info
    print(f" You accumulated",points)
    if points >= 70:
        print("Congratulation",user_info[0],"you are a good candidate. Tomorrow you will find a",user_info[1],"private jet to pick you up to",user_info[2],"where i will be waiting for you")
        exit(0)
    else:
        fail()

intro()
# Out:
#         Before starting the game i would like to know you
#
#
#         How would you like to be called?
#
# >
# skan
#
#         What is your favourite color
#
# >
# red
#
#         What is your destination for the trip of your dreams?
#
# >
# maldives
#
#         Welcome to the first stage, In this stage you will have to answer 4 questions. Only ONE WORD or a NUMBER are considered as an answer ..
#
#
#         Let's get started with the first question.
#
#
#         Jimmy's mother have four children: Monday, Tuesday,Wednesday and ...?
#
# >
# jimmy
# You are smart, keep going
# "
#     in a year there are 12 months, seven months have 31 days. How many months have 28 days
#
# >
# 12
# You are smart, keep going
# "
#     Mr and Mrs smith have 6 daughters and each daughter has two brothers. How many people are in the smith family?
#
# >
# 10
# You are smart, keep going
# 30
#
#     1=5
#
#     2=25
#
#     3=325
#
#     4=4325
#
#     5=?
#
# >
# 1
#
# ...
